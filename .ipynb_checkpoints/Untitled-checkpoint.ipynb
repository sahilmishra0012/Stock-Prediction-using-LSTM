# %%
import create_data

# %%
data=create_data.daata()

# %%
columns=data[0].split(',')

# %%
columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
data=data[1:]

# %%
data_new=[]
for i in data:
    data_new.append(i.split(','))

# %%
import pandas as pd

# %%
df=pd.DataFrame(data_new,columns=columns)

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-08-19  1190.089966  1206.989990  1190.089966  1198.449951
# 1   2019-08-20  1195.250000  1196.060059  1182.109985  1182.689941
# 2   2019-08-21  1193.150024  1199.000000  1187.430054  1191.250000
# 3   2019-08-22  1194.069946  1198.011963  1178.579956  1189.530029
# 4   2019-08-23  1181.989990  1194.079956  1147.750000  1151.290039
# 5   2019-08-26  1157.260010  1169.469971  1152.959961  1168.890015
# 6   2019-08-27  1180.530029  1182.400024  1161.449951  1167.839966
# 7   2019-08-28  1161.709961  1176.420044  1157.300049  1171.020020
# 8   2019-08-29  1181.119995  1196.060059  1181.119995  1192.849976
# 9   2019-08-30  1198.500000  1198.500000  1183.802979  1188.099976
# 10  2019-09-03  1177.030029  1186.890015  1163.199951  1168.390015
# 11  2019-09-04  1176.709961  1183.479980  1171.000000  1181.410034
# 12  2019-09-05  1191.530029  1213.040039  1191.530029  1211.380005
# ...

# %%
data_new
# Out:
# [['2019-08-19',
#   '1190.089966',
#   '1206.989990',
#   '1190.089966',
#   '1198.449951',
#   '1198.449951',
#   '1231600'],
#  ['2019-08-20',
#   '1195.250000',
#   '1196.060059',
#   '1182.109985',
#   '1182.689941',
#   '1182.689941',
#   '915500'],
#  ['2019-08-21',
#   '1193.150024',
#   '1199.000000',
#   '1187.430054',
#   '1191.250000',
#   '1191.250000',
#   '740700'],
#  ['2019-08-22',
#   '1194.069946',
#   '1198.011963',
#   '1178.579956',
#   '1189.530029',
#   '1189.530029',
#   '947500'],
#  ['2019-08-23',
#   '1181.989990',
#   '1194.079956',
#   '1147.750000',
#   '1151.290039',
#   '1151.290039',
#   '1687000'],
#  ['2019-08-26',
#   '1157.260010',
#   '1169.469971',
#   '1152.959961',
#   '1168.890015',
#   '1168.890015',
#   '1226100'],
#  ['2019-08-27',
#   '1180.530029',
#   '1182.400024',
#   '1161.449951',
#   '1167.839966',
#   '1167.839966',
#   '1077200'],
#  ['2019-08-28',
#   '1161.709961',
#   '1176.420044',
#   '1157.300049',
#   '1171.020020',
# ...
